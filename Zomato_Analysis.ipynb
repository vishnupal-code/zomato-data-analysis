# %% [markdown]
# <a href="https://colab.research.google.com/github/vishnupal-code/zomato-data-analysis/blob/main/Zomato_Analysis.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# !ls /content/drive/MyDrive
# Out:
# 'Colab Notebooks'
# 'Cover Letter Vishnu Pal Singh.gslides'
# 'Data Analytics Certificate glossary.gdoc'
# 'Goklyn Internship Agreement.gdoc'
# 'Goklyn Internship Agreement.pdf'
#  interview_preparation_plan.csv
# 'Monthly sales template.gsheet'
#  PHOTO-2024-11-21-12-58-32.jpg
#  Prayogam_2025_rAHUL2.gslides
# 'Prayogam 2025 rahul.gslides'
# 'Presentation Format.gslides'
#  Resume
# 'Untitled document (1).gdoc'
# 'Untitled document (2).gdoc'
# 'Untitled document (3).gdoc'
# 'Untitled document.gdoc'
# 'Untitled presentation (1).gslides'
# 'Untitled presentation.gslides'
# 'Untitled spreadsheet (1).gsheet'
# 'Untitled spreadsheet (2).gsheet'
# 'Untitled spreadsheet (3).gsheet'
# 'Untitled spreadsheet.gsheet'
# 'VARDHMAN MAHAVEER OPEN UNIVERSITY, KOTA.pdf'
# 'Vishnupal_AI&DS (1).pdf'
# 'Vishnupal_AI&DS.pdf'
#  Vishnu_Pal_Data-Analyst...gdoc
#  Vishnu_Pal_Data-Analyst.pdf
#  VishnuPalSinghResume.gdoc
#  Vishnu_Singh_DataScientist-resume.pdf
# 'VivekTak_Offer Letter.gdoc'
# ...

# %%
# !ls /content/drive/MyDrive/Zomato_csv/
# Out:
# zomato.csv

# %%
import pandas as pd

# Load from Google Drive (adjust path if your CSV is in a folder)
file_path = '/content/drive/MyDrive/Zomato_csv/zomato.csv' # ✅ Update only if it's in a subfolder
df = pd.read_csv(file_path)

# Preview first few rows
df.head()
# Out:
#                                                  url  \
# 0  https://www.zomato.com/bangalore/jalsa-banasha...
# 1  https://www.zomato.com/bangalore/spice-elephan...
# 2  https://www.zomato.com/SanchurroBangalore?cont...
# 3  https://www.zomato.com/bangalore/addhuri-udupi...
# 4  https://www.zomato.com/bangalore/grand-village...
#
#                                              address                   name  \
# 0  942, 21st Main Road, 2nd Stage, Banashankari, ...                  Jalsa
# 1  2nd Floor, 80 Feet Road, Near Big Bazaar, 6th ...         Spice Elephant
# 2  1112, Next to KIMS Medical College, 17th Cross...        San Churro Cafe
# 3  1st Floor, Annakuteera, 3rd Stage, Banashankar...  Addhuri Udupi Bhojana
# 4  10, 3rd Floor, Lakshmi Associates, Gandhi Baza...          Grand Village
#
#   online_order book_table   rate  votes                             phone  \
# 0          Yes        Yes  4.1/5    775    080 42297555\r\n+91 9743772233
# ...
